# %%
nama = "VINCENT"
TTL = "PONTIANAK, 17-03-2002"
JK = "LAKI-LAKI"
GolDarah= "B"
Alamat = "GG.MERAK 3 NO.91"
RT_RW = "001/008"
Kelurahan = "MARIANA"
Kecamatan = "PONTIANAK KOTA"
Agama = "KATHOLIK"
menikah = False
Pekerjaan = False
Kewarganegaraan = "WNI"
Berlaku = "SEUMUR HIDUP"

print ("============KARTU TANDA PENDUDUK=============")
print("Nama                 : ", nama)
print("Tempat/Tgl Lahir     : ", TTL)
print("Gol. Darah           : ", GolDarah)
print("Jenis Kelamin        : ", JK)
print("Alamat               : ", Alamat)
print("    RT/RW            : ", RT_RW)
print("    Kel/Desa         : ", Kelurahan)
print("    Kecamatan        : ", Kecamatan)
print("Agama                : ", Agama)
if(menikah):
    print("Status Perkawinan     :  Menikah")
else :
    print ("Status Perkawinan    :  Belum Menikah")

if(Pekerjaan):
    print("Pekerjaan            :  BEKERJA")
else :
    print("Pekerjaan            :  BELUM/TIDAK BEKERJA")
    
print("Kewarganegaraan      : ", Kewarganegaraan)
print("Berlaku Hingga       : ", Berlaku)
print("==============================================")
# Out:
# ============KARTU TANDA PENDUDUK=============
# Nama                 :  VINCENT
# Tempat/Tgl Lahir     :  PONTIANAK, 17-03-2002
# Gol. Darah           :  B
# Jenis Kelamin        :  LAKI-LAKI
# Alamat               :  GG.MERAK 3 NO.91
#     RT/RW            :  001/008
#     Kel/Desa         :  MARIANA
#     Kecamatan        :  PONTIANAK KOTA
# Agama                :  KATHOLIK
# Status Perkawinan    :  Belum Menikah
# Pekerjaan            :  BELUM/TIDAK BEKERJA
# Kewarganegaraan      :  WNI
# Berlaku Hingga       :  SEUMUR HIDUP
# ...

# %%
nama = "VINCENT"
Alamat = """GG.MERAK 3 NO.91
                  MARIANA, PONTIANAK KOTA
                  KOTA PONTIANAK"""
Tempat = "PONTIANAK"
TLahir = "17-03-2002"
Tinggi = "176 cm"
Pekerjaan = "PELAJAR"
No_SIM = "020310140114"
Berlaku = "17-03-2024"

print ("===============KARTU SIM A===================")
print("Nama           : ", nama)
print("Alamat         : ", Alamat)
print("Tempat&        : ", Tempat)
print("Tgl Lahir      : ", TLahir)
print("Tinggi         : ", Tinggi)
print("Pekerjaan      : ", Pekerjaan)
print("No. SIM        : ", No_SIM)
print("Berlaku s/d    : ", Berlaku)
print("==============================================")
# Out:
# ===============KARTU SIM A===================
# Nama           :  VINCENT
# Alamat         :  GG.MERAK 3 NO.91
#                   MARIANA, PONTIANAK KOTA
#                   KOTA PONTIANAK
# Tempat&        :  PONTIANAK
# Tgl Lahir      :  17-03-2002
# Tinggi         :  176 cm
# Pekerjaan      :  PELAJAR
# No. SIM        :  020310140114
# Berlaku s/d    :  17-03-2024
# ...

# %%
nama = "Vincent"
alamat = "Jalan Pak Kasih GG.Merak 3 NO.91"
no = "0896-8954-6108"
email = "vincen.******@gmail,com"
pendidikan = """TK SUSTER PONTIANAK
                    SD SUSTER PONTIANAK
                    SMP SUSTER PONTIANAK
                    SMA SANTO PAULUS PONTIANAK
                    STMIK PONTIANAK"""
ekstrakulikuler = """PADA SAAT BERADA DI SMP
                    Ekstrakulikuler Drumband
                    Osis SMP SUSTER PONTIANAK
                    PADA SAAT SMA
                    Ekstrakulikuler Drumband"""
Pekerjaan = False
prestasi = """Pada saat SMP pernah meraih
                    -Juara 2 tingkat SMP
                    
                    Pada saat SMA pernah meraih
                    -Banyak penghargaan untuk anggota
                     Drumband"""

print("=======================BIODATA=======================")
print("Nama             : ", nama)
print("Alamat           : ", alamat)
print("No.Telp          : ", no)
print("Email            : ", email)
print("=====================================================")
print("Pendidikan       : ", pendidikan)
print("=====================================================")
print("Ekstrakulikuler  : ", ekstrakulikuler)
print("=====================================================")
if(Pekerjaan):
    print("Pengalaman Kerja :  SUDAH ADA PENGALAMAN")
else :
    print("Pengalaman Kerja :  BELUM ADA PENGALAMAN")

print("Hobi             :  Bermain game")
print("Prestasi         : ", prestasi)
print("=====================TENTANG SAYA====================")
# Out:
# =======================BIODATA=======================
# Nama             :  Vincent
# Alamat           :  Jalan Pak Kasih GG.Merak 3 NO.91
# No.Telp          :  0896-8954-6108
# Email            :  vincen.******@gmail,com
# ...
# Pendidikan       :  TK SUSTER PONTIANAK
#                     SD SUSTER PONTIANAK
#                     SMP SUSTER PONTIANAK
#                     SMA SANTO PAULUS PONTIANAK
#                     STMIK PONTIANAK
# ...
# Ekstrakulikuler  :  PADA SAAT BERADA DI SMP
#                     Ekstrakulikuler Drumband
#                     Osis SMP SUSTER PONTIANAK
#                     PADA SAAT SMA
#                     Ekstrakulikuler Drumband
# ...
# Pengalaman Kerja :  BELUM ADA PENGALAMAN
# Hobi             :  Bermain game
# Prestasi         :  Pada saat SMP pernah meraih
#                     -Juara 2 tingkat SMP
#
#                     Pada saat SMA pernah meraih
#                     -Banyak penghargaan untuk anggota
#                      Drumband
# ...
